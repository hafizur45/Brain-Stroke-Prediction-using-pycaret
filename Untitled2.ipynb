# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizur45/Brain-Stroke-Prediction-using-pycaret/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#dataset uploaded
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-eb457869-da79-4b22-9e26-ccc172a8e272" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb457869-da79-4b22-9e26-ccc172a8e272">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#read the csv value
df = pd.read_csv("healthcare-dataset-stroke-data.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# null values
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Let's get an overview of features datatype
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
columns_to_convert = ['hypertension', 'heart_disease', 'stroke']
df[columns_to_convert] = df[columns_to_convert].astype(str)

# %%
# Drop ID - I think, ID won't useful in our analysis.
df.drop('id', axis= 1, inplace= True)

# %%
# categorical and numeric features
cat_features = df.select_dtypes(exclude="number").columns
num_cols = df.select_dtypes(include="number").columns
print('Categorical Features are: ', cat_features)
print('Numerical Features are: ', num_cols)
# Out:
# Categorical Features are:  Index(['gender', 'hypertension', 'heart_disease', 'ever_married', 'work_type',
#        'Residence_type', 'smoking_status', 'stroke'],
#       dtype='object')
# Numerical Features are:  Index(['age', 'avg_glucose_level', 'bmi'], dtype='object')

# %%
# Calculate the mode of the column
mode_value = df['bmi'].mode()[0]

# Replace null values with the mode
df['bmi'].fillna(mode_value, inplace=True)

# %%
# null values
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.head()
# Out:
#    gender   age hypertension heart_disease ever_married      work_type  \
# 0    Male  67.0            0             1          Yes        Private
# 1  Female  61.0            0             0          Yes  Self-employed
# 2    Male  80.0            0             1          Yes        Private
# 3  Female  49.0            0             0          Yes        Private
# 4  Female  79.0            1             0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status stroke
# 0          Urban             228.69  36.6  formerly smoked      1
# 1          Rural             202.21  28.7     never smoked      1
# 2          Rural             105.92  32.5     never smoked      1
# 3          Urban             171.23  34.4           smokes      1
# 4          Rural             174.12  24.0     never smoked      1

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension          object
# heart_disease         object
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                object
# dtype: object

# %%
#data Preprocessing

# %%
#Storing in X and y
#data separate and storing in x and y
#data separate
x=df.iloc[:,:-1]
x
# Out:
#       gender   age hypertension heart_disease ever_married      work_type  \
# 0       Male  67.0            0             1          Yes        Private
# 1     Female  61.0            0             0          Yes  Self-employed
# 2       Male  80.0            0             1          Yes        Private
# 3     Female  49.0            0             0          Yes        Private
# 4     Female  79.0            1             0          Yes  Self-employed
# ...      ...   ...          ...           ...          ...            ...
# 5105  Female  80.0            1             0          Yes        Private
# 5106  Female  81.0            0             0          Yes  Self-employed
# 5107  Female  35.0            0             0          Yes  Self-employed
# 5108    Male  51.0            0             0          Yes        Private
# 5109  Female  44.0            0             0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status
# ...

# %%
y=df.iloc[:,10]
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: object

# %%
#count class 0 and 1
df.groupby('stroke').size()
# Out:
# stroke
# 0    4861
# 1     249
# dtype: int64

# %%
# Counting values in the 'Target' column
target_temp = df['stroke'].value_counts()

# Creating a bar plot with different colors for 'yes' and 'no'
fig = px.bar(x=target_temp.index, y=target_temp.values, labels={'x': 'stroke', 'y': 'Count'},
             title='Count of Yes/No in stroke Column', color=target_temp.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
legend_dict = {0: 'NO', 1: 'YES'}

Patient_Status = df['stroke'].value_counts()
transactions = Patient_Status.index
quantity = Patient_Status.values

figure = px.pie(names=legend_dict.values(), values=quantity, title="Patient Status")
figure.update_traces(textposition='inside', textinfo='percent+label')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
stage = df["smoking_status"].value_counts()
transactions = stage.index
quantity = stage.values

figure = px.pie(df,
             values=quantity,
             names=transactions, hole = 0.5,
             title="Alcohol")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
histology = df["Residence_type"].value_counts()
transactions = histology.index
quantity = histology.values

figure = px.pie(df,
             values=quantity,
             names=transactions,hole = 0.5,
             title="Residence_type")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
histology = df["work_type"].value_counts()
transactions = histology.index
quantity = histology.values

figure = px.pie(df,
             values=quantity,
             names=transactions,hole = 0.5,
             title="work_type")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# # Creating boxplots using Plotly Express
# fig = px.box(df, y=['Age', 'bmi'])
# fig.update_layout(yaxis_title='Values', xaxis_title='Variables')
# fig.show()

# %%
df.shape
# Out:
# (5110, 11)

# %%
df.drop(df.loc[df['gender'] == 'Other'].index, inplace= True)

# %%
df.shape
# Out:
# (5109, 11)

# %%
#Encoding

# %%
df['gender'] = df['gender'].map({'Female': 1, 'Male': 0})

# %%
df.head()
# Out:
#    gender   age hypertension heart_disease ever_married      work_type  \
# 0       0  67.0            0             1          Yes        Private
# 1       1  61.0            0             0          Yes  Self-employed
# 2       0  80.0            0             1          Yes        Private
# 3       1  49.0            0             0          Yes        Private
# 4       1  79.0            1             0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status stroke
# 0          Urban             228.69  36.6  formerly smoked      1
# 1          Rural             202.21  28.7     never smoked      1
# 2          Rural             105.92  32.5     never smoked      1
# 3          Urban             171.23  34.4           smokes      1
# 4          Rural             174.12  24.0     never smoked      1

# %%
# convert target variabe stroke into integer format
df['stroke'] = df['stroke'].map({'0': 0, '1': 1})
# convert target variabe stroke into integer format
df['ever_married'] = df['ever_married'].map({'No': 0, 'Yes': 1})

# %%
df.head()
# Out:
#    gender   age hypertension heart_disease  ever_married      work_type  \
# 0       0  67.0            0             1             1        Private
# 1       1  61.0            0             0             1  Self-employed
# 2       0  80.0            0             1             1        Private
# 3       1  49.0            0             0             1        Private
# 4       1  79.0            1             0             1  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21  28.7     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df=df[["age","hypertension","heart_disease","ever_married","avg_glucose_level","bmi","stroke"]]

# %%
x=df.iloc[:,:-1]
x
# Out:
#        age hypertension heart_disease  ever_married  avg_glucose_level   bmi
# 0     67.0            0             1             1             228.69  36.6
# 1     61.0            0             0             1             202.21  28.7
# 2     80.0            0             1             1             105.92  32.5
# 3     49.0            0             0             1             171.23  34.4
# 4     79.0            1             0             1             174.12  24.0
# ...    ...          ...           ...           ...                ...   ...
# 5105  80.0            1             0             1              83.75  28.7
# 5106  81.0            0             0             1             125.20  40.0
# 5107  35.0            0             0             1              82.99  30.6
# 5108  51.0            0             0             1             166.29  25.6
# 5109  44.0            0             0             1              85.28  26.2
#
# [5109 rows x 6 columns]

# %%
y=df.iloc[:,6]
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5109, dtype: int64

# %%
#Feature Selection

# %%
#Feature Selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
fit_feature = SelectKBest(score_func=f_classif, k='all')
fit_feature.fit(x, y)
# Out:
# SelectKBest(k='all')

# %%
#kon column koto importent tar score
score_column=pd.DataFrame(fit_feature.scores_,columns=['Score Value'])
score_column
# Out:
#    Score Value
# 0   326.799849
# 1    84.919947
# 2    94.666779
# 3    60.609558
# 4    90.550026
# 5     7.472000

# %%
#Feature Importance
from sklearn.ensemble import ExtraTreesClassifier

# %%
model=ExtraTreesClassifier()

# %%
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
model.feature_importances_
# Out:
# array([0.27277505, 0.01672352, 0.01709552, 0.01364765, 0.36235636,
#        0.31740189])

# %%
top=pd.Series(model.feature_importances_,index=x.columns)
top
# Out:
# age                  0.272775
# hypertension         0.016724
# heart_disease        0.017096
# ever_married         0.013648
# avg_glucose_level    0.362356
# bmi                  0.317402
# dtype: float64

# %%
top.nlargest(5).plot(kind='barh')#bar #barh #plot() #hist #box #pie
# Out:
# <AxesSubplot: >

# %%
# df=df[["Age","Cholesterol Level","Systolic Blood Pressure","Diastolic Blood Pressure","Body Mass Index (BMI)","Glucose Level","Target"]]

# %%
df.head()
# Out:
#     age hypertension heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0            0             1             1             228.69  36.6
# 1  61.0            0             0             1             202.21  28.7
# 2  80.0            0             1             1             105.92  32.5
# 3  49.0            0             0             1             171.23  34.4
# 4  79.0            1             0             1             174.12  24.0
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# info = ["age","height","weight","high blood pressure","low blood pressure","1:low cholestoral,2:mid cholestoral,3:high cholestoral","1:gluc low,2:gluc high","0:No smoke, 1:smoker","0:No exercise,1:Yes exercise","0:No Heart problem,1: Heart Problem"]



# for i in range(len(info)):
#     print(df.columns[i]+":\t\t\t"+info[i])

# %%
#describe all thing
df.describe()
# Out:
#                age  ever_married  avg_glucose_level          bmi       stroke
# count  5109.000000   5109.000000        5109.000000  5109.000000  5109.000000
# mean     43.229986      0.656293         106.140399    28.886905     0.048738
# std      22.613575      0.474991          45.285004     7.698328     0.215340
# min       0.080000      0.000000          55.120000    10.300000     0.000000
# 25%      25.000000      0.000000          77.240000    23.800000     0.000000
# 50%      45.000000      1.000000          91.880000    28.400000     0.000000
# 75%      61.000000      1.000000         114.090000    32.800000     0.000000
# max      82.000000      1.000000         271.740000    97.600000     1.000000

# %%
df.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'ever_married',
#        'avg_glucose_level', 'bmi', 'stroke'],
#       dtype='object')

# %%
pip install pycaret

# %%
pip install mlflow

# %%
# # Assuming df is your DataFrame

# columns_to_drop = [
#     'Gender', 'Hypertension', 'Diabetes','Heart Disease','CT Scan Results','Family History of Stroke','Physical Activity','Smoking History','MRI Scan Results','Alcohol Consumption'
#     # Add other column names you want to drop here
# ]

# df.drop(columns=columns_to_drop, inplace=True)

# %%
df
# Out:
#        age hypertension heart_disease  ever_married  avg_glucose_level   bmi  \
# 0     67.0            0             1             1             228.69  36.6
# 1     61.0            0             0             1             202.21  28.7
# 2     80.0            0             1             1             105.92  32.5
# 3     49.0            0             0             1             171.23  34.4
# 4     79.0            1             0             1             174.12  24.0
# ...    ...          ...           ...           ...                ...   ...
# 5105  80.0            1             0             1              83.75  28.7
# 5106  81.0            0             0             1             125.20  40.0
# 5107  35.0            0             0             1              82.99  30.6
# 5108  51.0            0             0             1             166.29  25.6
# 5109  44.0            0             0             1              85.28  26.2
#
#       stroke
# 0          1
# 1          1
# ...

# %%
from pycaret.classification import *

# %%
cancer = setup(data = df, target = 'stroke',
                  normalize = True,
                  transformation = True,
                  log_experiment = True,
                  remove_multicollinearity = True, #Drop one of the two features that are highly correlated with each other
                  numeric_imputation='median',
                  fold = 5,
                  #ignore_features=['Patient_ID'],
                  #date_features=['Date_of_Surgery','Date_of_Last_Visit'],
                  #fix_imbalance = False,
                  train_size = 0.70
          )
# Out:
# <style type="text/css">
# #T_2a7fc_row10_col1, #T_2a7fc_row16_col1, #T_2a7fc_row18_col1, #T_2a7fc_row20_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2a7fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a7fc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2a7fc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a7fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a7fc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2a7fc_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_2a7fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2a7fc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2a7fc_row1_col1" class="data row1 col1" >stroke</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Buildin ML Models
#
# 'lr' - Logistic Regression 'knn' - K Neighbors Classifier 'nb' - Naive Bayes 'dt' - Decision Tree Classifier 'svm' - SVM - Linear Kernel 'rbfsvm' - SVM - Radial Kernel 'gpc' - Gaussian Process Classifier 'mlp' - MLP Classifier 'ridge' - Ridge Classifier 'rf' - Random Forest Classifier 'qda' - Quadratic Discriminant Analysis 'ada' - Ada Boost Classifier 'gbc' - Gradient Boosting Classifier 'lda' - Linear Discriminant Analysis 'et' - Extra Trees Classifier 'xgboost' - Extreme Gradient Boosting 'lightgbm' - Light Gradient Boosting Machine 'catboost' - CatBoost Classifier bold text

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_40d3d_row5_col0, #T_40d3d_row5_col1, #T_40d3d_row5_col2, #T_40d3d_row5_col3, #T_40d3d_row5_col4, #T_40d3d_row5_col5, #T_40d3d_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_40d3d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40d3d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_40d3d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_40d3d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_40d3d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_40d3d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_40d3d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_40d3d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# check all available config
get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %%
get_config('X_test')
# Out:
#        age hypertension heart_disease  ever_married  avg_glucose_level  \
# 3555   9.0            0             0             0          87.739998
# 1239  26.0            0             0             0          89.300003
# 3454  62.0            0             0             1          60.389999
# 2055  62.0            0             0             1          83.849998
# 4498  62.0            0             0             1         128.610001
# ...    ...          ...           ...           ...                ...
# 765   56.0            0             0             1         114.209999
# 2446  80.0            0             0             1          64.150002
# 4381  37.0            0             0             0          90.709999
# 4286   3.0            0             0             0         194.750000
# 175   72.0            1             0             1         185.490005
#
#             bmi
# 3555  17.100000
# 1239  48.400002
# 3454  26.900000
# 2055  24.500000
# 4498  24.799999
# ...

# %%
get_config('X_test_transformed')
# Out:
#            age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 3555 -1.541629     -0.333540      -0.235563     -1.373389          -0.193254
# 1239 -0.714141     -0.333540      -0.235563     -1.373389          -0.133495
# 3454  0.824082     -0.333540      -0.235563      0.728126          -1.754426
# 2055  0.824082     -0.333540      -0.235563      0.728126          -0.352155
# 4498  0.824082     -0.333540      -0.235563      0.728126           0.885952
# ...        ...           ...            ...           ...                ...
# 765   0.579300     -0.333540      -0.235563      0.728126           0.595685
# 2446  1.539558     -0.333540      -0.235563      0.728126          -1.459426
# 4381 -0.223355     -0.333540      -0.235563     -1.373389          -0.081285
# 4286 -1.877521     -0.333540      -0.235563     -1.373389           1.658224
# 175   1.224758      2.998137      -0.235563      0.728126           1.584007
#
#            bmi
# 3555 -1.848592
# ...

# %%
get_config('target_param')
# Out:
# 'stroke'

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_a9abd th {
#   text-align: left;
# }
# ...

# %%
ridge = create_model('ridge')
# Out:
# <style type="text/css">
# #T_49667_row5_col0, #T_49667_row5_col1, #T_49667_row5_col2, #T_49667_row5_col3, #T_49667_row5_col4, #T_49667_row5_col5, #T_49667_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_49667" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49667_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_49667_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_49667_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_49667_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_49667_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_49667_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_49667_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(ridge)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
unseen_predictions = predict_model(rf, data = df)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_60ed2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60ed2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_60ed2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_60ed2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_60ed2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_60ed2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_60ed2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_60ed2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_60ed2_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60ed2_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_75d50_row5_col0, #T_75d50_row5_col1, #T_75d50_row5_col2, #T_75d50_row5_col3, #T_75d50_row5_col4, #T_75d50_row5_col5, #T_75d50_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_75d50" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75d50_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_75d50_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_75d50_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_75d50_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_75d50_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_75d50_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_75d50_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
dt_predictions = predict_model(dt, data = df)
dt_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c791f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c791f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c791f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c791f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c791f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c791f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c791f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c791f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c791f_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c791f_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
svm = create_model('svm')
# Out:
# <style type="text/css">
# #T_1f0ec_row5_col0, #T_1f0ec_row5_col1, #T_1f0ec_row5_col2, #T_1f0ec_row5_col3, #T_1f0ec_row5_col4, #T_1f0ec_row5_col5, #T_1f0ec_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1f0ec" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f0ec_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1f0ec_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1f0ec_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1f0ec_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1f0ec_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1f0ec_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1f0ec_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
svm_predictions = predict_model(svm, data = df)
svm_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_71860" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71860_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_71860_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_71860_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_71860_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_71860_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_71860_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_71860_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_71860_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71860_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
lr = create_model('lr')
evaluate_model(lr)
# Out:
# <style type="text/css">
# #T_b3056_row5_col0, #T_b3056_row5_col1, #T_b3056_row5_col2, #T_b3056_row5_col3, #T_b3056_row5_col4, #T_b3056_row5_col5, #T_b3056_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b3056" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3056_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b3056_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b3056_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b3056_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b3056_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b3056_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b3056_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
unseen_predictions = predict_model(lr, data = df)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c99e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c99e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6c99e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6c99e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6c99e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6c99e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6c99e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6c99e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6c99e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c99e_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(dt, plot = 'confusion_matrix')

# %%
corr_matrix = df.corr()

# %%
sns.heatmap(corr_matrix, annot=True)
# Out:
# <AxesSubplot: >
